# %%
import pandas as pd
d=pd.read_csv('/content/employees details.csv')
print(d)
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
df=pd.DataFrame(d)
print("Columns",df.columns)
# Out:
# Columns Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Salary'],
#       dtype='object')

# %%
#Get the shape-(no.of rows,no.of columns)
print(df.shape)
print("Salary",df['Salary'])
# Out:
# (100, 11)
# Salary 0     168251
# 1      51063
# 2      50155
# 3     180294
# 4     117642
#        ...
# 95    129774
# 96    156194
# 97     95673
# 98     51015
# 99     93650
# Name: Salary, Length: 100, dtype: int64

# %%
print("particular person details",df.loc[8])
# Out:
# particular person details Emp ID                                   477616
# Name Prefix                                Hon.
# First Name                              Frances
# Middle Initial                                B
# Last Name                                 Young
# Gender                                        F
# E Mail                  frances.young@gmail.com
# Father's Name                        Fred Young
# Mother's Name                     Lillian Young
# Mother's Maiden Name                       Diaz
# Salary                                   121587
# Name: 8, dtype: object

# %%
print(d.loc[d['Salary']==121587])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 8  477616        Hon.    Frances              B     Young      F
#
#                     E Mail Father's Name  Mother's Name Mother's Maiden Name  \
# 8  frances.young@gmail.com    Fred Young  Lillian Young                 Diaz
#
#    Salary
# 8  121587

# %%
df=d['Salary']/999
print(df)
# Out:
# 0     168.419419
# 1      51.114114
# 2      50.205205
# 3     180.474474
# 4     117.759760
#          ...
# 95    129.903904
# 96    156.350350
# 97     95.768769
# 98     51.066066
# 99     93.743744
# Name: Salary, Length: 100, dtype: float64

# %%
df=d['Salary']/5
print("\Make ab average of total marks:\n",df)
# Out:
# \Make ab average of total marks:
#  0     33650.2
# 1     10212.6
# 2     10031.0
# 3     36058.8
# 4     23528.4
#        ...
# 95    25954.8
# 96    31238.8
# 97    19134.6
# 98    10203.0
# 99    18730.0
# Name: Salary, Length: 100, dtype: float64
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# /tmp/ipython-input-1039585866.py:2: SyntaxWarning: invalid escape sequence '\M'
#   print("\Make ab average of total marks:\n",df)
